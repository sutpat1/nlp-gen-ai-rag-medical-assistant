# %% [markdown]
# ## Problem Statement

# %% [markdown]
# ### Business Context

# %% [markdown]
# The healthcare industry is rapidly evolving, with professionals facing increasing challenges in managing vast volumes of medical data while delivering accurate and timely diagnoses. The need for quick access to comprehensive, reliable, and up-to-date medical knowledge is critical for improving patient outcomes and ensuring informed decision-making in a fast-paced environment.
#
# Healthcare professionals often encounter information overload, struggling to sift through extensive research and data to create accurate diagnoses and treatment plans. This challenge is amplified by the need for efficiency, particularly in emergencies, where time-sensitive decisions are vital. Furthermore, access to trusted, current medical information from renowned manuals and research papers is essential for maintaining high standards of care.
#
# To address these challenges, healthcare centers can focus on integrating systems that streamline access to medical knowledge, provide tools to support quick decision-making, and enhance efficiency. Leveraging centralized knowledge platforms and ensuring healthcare providers have continuous access to reliable resources can significantly improve patient care and operational effectiveness.

# %% [markdown]
# **Common Questions to Answer**
#
# **1. Diagnostic Assistance**: "What are the common symptoms and treatments for pulmonary embolism?"
#
# **2. Drug Information**: "Can you provide the trade names of medications used for treating hypertension?"
#
# **3. Treatment Plans**: "What are the first-line options and alternatives for managing rheumatoid arthritis?"
#
# **4. Specialty Knowledge**: "What are the diagnostic steps for suspected endocrine disorders?"
#
# **5. Critical Care Protocols**: "What is the protocol for managing sepsis in a critical care unit?"

# %% [markdown]
# ### Objective

# %% [markdown]
# As an AI specialist, your task is to develop a RAG-based AI solution using renowned medical manuals to address healthcare challenges. The objective is to **understand** issues like information overload, **apply** AI techniques to streamline decision-making, **analyze** its impact on diagnostics and patient outcomes, **evaluate** its potential to standardize care practices, and **create** a functional prototype demonstrating its feasibility and effectiveness.

# %% [markdown]
# ### Data Description

# %% [markdown]
# The **Merck Manuals** are medical references published by the American pharmaceutical company Merck & Co., that cover a wide range of medical topics, including disorders, tests, diagnoses, and drugs. The manuals have been published since 1899, when Merck & Co. was still a subsidiary of the German company Merck.
#
# The manual is provided as a PDF with over 4,000 pages divided into 23 sections.

# %% [markdown]
# ## Installing and Importing Necessary Libraries and Dependencies

# %%
# Installation for GPU llama-cpp-python
# uncomment and run the following code in case GPU is being used
# !CMAKE_ARGS="-DLLAMA_CUBLAS=on" FORCE_CMAKE=1 pip install llama-cpp-python===0.1.85 --force-reinstall --no-cache-dir -q

# Installation for CPU llama-cpp-python
# uncomment and run the following code in case GPU is not being used
# !CMAKE_ARGS="-DLLAMA_CUBLAS=off" FORCE_CMAKE=1 pip install llama-cpp-python --force-reinstall --no-cache-dir -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 27.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 299.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 203.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 193.1 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.5.0 which is incompatible.

# %% [markdown]
# **Note**:
# - After running the above cell, kindly restart the runtime (for Google Colab) or notebook kernel (for Jupyter Notebook), and run all cells sequentially from the next cell.
# - On executing the above line of code, you might see a warning regarding package dependencies. This error message can be ignored as the above code ensures that all necessary libraries and their dependencies are maintained to successfully execute the code in ***this notebook***.

# %%
# For installing the libraries & downloading models from HF Hub
# !pip install huggingface_hub==0.35.3 pandas==2.2.2 tiktoken==0.12.0 pymupdf==1.26.5 langchain==0.3.27 langchain-community==0.3.31 chromadb==1.1.1 sentence-transformers==5.1.1 numpy==2.3.3 -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 4.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 5.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 564.3/564.3 kB 22.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 58.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.1/24.1 MB 87.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 62.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 105.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.9/19.9 MB 95.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.6/486.6 kB 35.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 102.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 23.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# **Note**:
# - After running the above cell, kindly restart the runtime (for Google Colab) or notebook kernel (for Jupyter Notebook), and run all cells sequentially from the next cell.
# - On executing the above line of code, you might see a warning regarding package dependencies. This error message can be ignored as the above code ensures that all necessary libraries and their dependencies are maintained to successfully execute the code in ***this notebook***.

# %%
#Libraries for processing dataframes,text
import json,os
import tiktoken
import pandas as pd

#Libraries for Loading Data, Chunking, Embedding, and Vector Databases
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import PyMuPDFLoader
from langchain_community.embeddings.sentence_transformer import SentenceTransformerEmbeddings
from langchain_community.vectorstores import Chroma

#Libraries for downloading and loading the llm
from huggingface_hub import hf_hub_download
from llama_cpp import Llama

# %% [markdown]
# ## Question Answering using LLM

# %% [markdown]
# #### Downloading and Loading the model

# %%
# the type of model and path
model_path = hf_hub_download(
    repo_id="TheBloke/Mistral-7B-Instruct-v0.2-GGUF",
    filename="mistral-7b-instruct-v0.2.Q4_K_M.gguf"
)

# %%
import llama_cpp
print(llama_cpp.__version__)
# Out:
# 0.1.85

# %%
# creating the llm model with layers
llm = Llama(
    model_path=model_path,
    n_ctx=2300,
    n_gpu_layers=38,
    n_batch=512
)
# Out:
# AVX = 1 | AVX2 = 1 | AVX512 = 0 | AVX512_VBMI = 0 | AVX512_VNNI = 0 | FMA = 1 | NEON = 0 | ARM_FMA = 0 | F16C = 1 | FP16_VA = 0 | WASM_SIMD = 0 | BLAS = 1 | SSE3 = 1 | SSSE3 = 1 | VSX = 0 |

# %% [markdown]
# #### Response

# %%
def response(query,max_tokens=300,temperature=0,top_p=0.95,top_k=50):
    model_output = llm(
      prompt=query,
      max_tokens=max_tokens,
      temperature=temperature,
      top_p=top_p,
      top_k=top_k
    )

    return model_output['choices'][0]['text']

# %% [markdown]
# ### Query 1: What is the protocol for managing sepsis in a critical care unit?
#
# > Add blockquote

# %%
query = "What is the protocol for managing sepsis in a critical care unit?"

print(response(query))
# Out:
# Sepsis is a life-threatening condition that can arise from an infection, and prompt recognition and appropriate management are crucial for improving outcomes. In a critical care unit, the following steps should be taken for managing sepsis:
#
# 1. Early recognition: Identify patients at risk of developing sepsis based on clinical suspicion, laboratory results, or vital sign abnormalities.
# 2. Rapid resuscitation: Administer fluids and vasopressors as needed to maintain adequate tissue perfusion and organ function.
# 3. Source control: Identify and address the source of infection, which may involve surgical intervention or other interventions such as drainage or debridement.
# 4. Antimicrobial therapy: Administer appropriate antimicrobial agents based on culture results or clinical suspicion.
# 5. Glucose control: Maintain strict glucose control to prevent hyperglycemia, which has been associated with worse outcomes in sepsis.
# ...

# %% [markdown]
# ### Query 2: What are the common symptoms for appendicitis, and can it be cured via medicine? If not, what surgical procedure should be followed to treat it?

# %%
query = "What are the common symptoms for appendicitis, and can it be cured via medicine? If not, what surgical procedure should be followed to treat it?"

print(response(query))
# Out:
# Llama.generate: prefix-match hit
# Appendicitis is a medical condition characterized by inflammation of the appendix, a small tube-shaped organ located in the lower right side of the abdomen. The symptoms of appendicitis can vary from person to person, but some common signs and symptoms include:
#
# 1. Abdominal pain: The pain may start as a mild discomfort in the lower right side of the abdomen that gradually worsens over time. It is often described as a dull ache or cramping sensation that may eventually become constant and severe.
# 2. Loss of appetite: People with appendicitis may lose their appetite due to the pain and discomfort in the abdomen.
# 3. Nausea and vomiting: Vomiting is a common symptom of appendicitis, especially if the inflammation is severe or if there is an obstruction of the appendix.
# 4. Fever: A fever may develop as the body responds to the infection.
# ...

# %% [markdown]
# ### Query 3: What are the effective treatments or solutions for addressing sudden patchy hair loss, commonly seen as localized bald spots on the scalp, and what could be the possible causes behind it?

# %%
query = "What are the effective treatments or solutions for addressing sudden patchy hair loss, commonly seen as localized bald spots on the scalp, and what could be the possible causes behind it?"

print(response(query))
# Out:
# Llama.generate: prefix-match hit
# Sudden patchy hair loss, also known as alopecia areata, is a common autoimmune disorder that affects the hair follicles. It can cause round or oval bald patches on the scalp, beard, or other areas of the body where hair grows. The exact cause of alopecia areata is not known, but it's believed to be related to an abnormal immune response that attacks the hair follicles.
#
# There are several treatments for addressing sudden patchy hair loss:
#
# 1. Corticosteroids: These medications can help reduce inflammation and suppress the immune system, allowing the hair to grow back. They can be applied topically or taken orally.
# 2. Immunotherapy: This involves using drugs that alter the immune response to promote hair growth. One such drug is minoxidil, which has been shown to be effective in some cases of alopecia areata.
# ...

# %% [markdown]
# ### Query 4:  What treatments are recommended for a person who has sustained a physical injury to brain tissue, resulting in temporary or permanent impairment of brain function?

# %%
query = "What treatments are recommended for a person who has sustained a physical injury to brain tissue, resulting in temporary or permanent impairment of brain function?"

print(response(query))
# Out:
# Llama.generate: prefix-match hit
# A person who has sustained a physical injury to the brain tissue may require various treatments depending on the severity and location of the injury. Here are some common treatments that may be recommended:
#
# 1. Emergency care: In case of a traumatic brain injury (TBI), it is essential to seek immediate medical attention. The primary goal of emergency care is to prevent further damage, stabilize the patient's condition, and ensure adequate oxygen supply to the brain.
# 2. Medications: Depending on the symptoms, healthcare professionals may prescribe medications to manage conditions such as seizures, pain, swelling, or infections. For instance, anti-inflammatory drugs, anticonvulsants, or steroids might be used.
# ...

# %% [markdown]
# ### Query 5: What are the necessary precautions and treatment steps for a person who has fractured their leg during a hiking trip, and what should be considered for their care and recovery?

# %%
query = "What are the necessary precautions and treatment steps for a person who has fractured their leg during a hiking trip, and what should be considered for their care and recovery?"

print(response(query))
# Out:
# Llama.generate: prefix-match hit
# First and foremost, it is essential to ensure the safety of the injured person. If possible, try to keep them calm and still to prevent further injury or discomfort. If the fracture is open (compound), take extra precautions to prevent infection by covering the wound with a clean dressing.
#
# Next, assess the severity of the fracture and determine if medical attention is required. If the person can walk with assistance or if the fracture is not displaced (meaning the bone ends are still aligned), they may be able to hike out with help. However, if the fracture is severe, displaced, or open, it is crucial to seek medical attention as soon as possible.
#
# If medical attention is not immediately available, follow these steps for temporary care and stabilization:
#
# 1. Immobilize the leg: Use a splint, sling, or other available materials to immobilize the leg above and below the fracture site. This will help prevent further injury and discomfort.
# ...

# %% [markdown]
# The answers all follow a certain bullet structure.

# %% [markdown]
# ## Question Answering using LLM with Prompt Engineering

# %% [markdown]
# This prompt ensures a correct mindset and knowledge base for the LLM to think about when answering.

# %%
prompt = """
You are a highly accurate medical assistant.

Use only factual medical knowledge. If you are unsure, clearly state that you are not certain.

Provide a structured and clear answer with the following sections:

1. Definition
2. Symptoms (if applicable)
3. Treatment / Management

Keep the response concise, medically accurate, and suitable for healthcare professionals.
"""

# %% [markdown]
# ### Query 1: What is the protocol for managing sepsis in a critical care unit?

# %%
query = "What is the protocol for managing sepsis in a critical care unit?"

print(response(prompt + query))
# Out:
# Llama.generate: prefix-match hit
# 1. Definition:
# Sepsis is a life-threatening condition caused by a dysregulated host response to infection. It can lead to tissue damage, organ failure, and even death if not recognized and treated promptly. Septic shock occurs when sepsis progresses to the point where vital organ functions are impaired.
#
# 2. Symptoms:
# Symptoms of sepsis include fever or hypothermia, tachycardia or bradycardia, respiratory distress, altered mental status, and lactic acidosis. In septic shock, there is evidence of decreased tissue perfusion such as low blood pressure, cool extremities, and urine output less than 20 mL/hour.
#
# 3. Treatment / Management:
# ...

# %% [markdown]
# ### Query 2: What are the common symptoms for appendicitis, and can it be cured via medicine? If not, what surgical procedure should be followed to treat it?

# %%
query = "What are the common symptoms for appendicitis, and can it be cured via medicine? If not, what surgical procedure should be followed to treat it?"

print(response(prompt + query))
# Out:
# Llama.generate: prefix-match hit
# 1. Definition:
# Appendicitis is an inflammatory condition of the appendix, a small pouch located in the lower right abdomen that extends from the cecum (the beginning of the large intestine). The most common cause is obstruction of its lumen by fecal matter or lymphoid hyperplasia.
#
# 2. Symptoms:
# - Sudden onset of pain, usually starting around the navel and then shifting to the right lower abdomen
# - Anorexia (loss of appetite)
# - Nausea and vomiting
# - Fever (often low-grade)
# - Abdominal tenderness, particularly when pressure is applied to the right lower quadrant
# - Rebound tenderness (pain worsens when pressure is released)
# - Guarding (muscle rigidity in response to pain)
#
# 3. Treatment / Management:
# ...

# %% [markdown]
# ### Query 3: What are the effective treatments or solutions for addressing sudden patchy hair loss, commonly seen as localized bald spots on the scalp, and what could be the possible causes behind it?

# %%
query = "What are the effective treatments or solutions for addressing sudden patchy hair loss, commonly seen as localized bald spots on the scalp, and what could be the possible causes behind it?"

print(response(prompt + query))
# Out:
# Llama.generate: prefix-match hit
# 1. Definition:
# Sudden patchy hair loss, also known as alopecia areata, is a common autoimmune disorder that results in the sudden loss of hair from specific areas of the scalp or other parts of the body. The exact cause of alopecia areata is unknown, but it's believed to be related to an abnormal immune response that attacks the hair follicles.
#
# 2. Symptoms:
# The primary symptom of alopecia areata is the sudden appearance of round or patchy bald spots on the scalp, although it can also affect other areas of the body such as the beard, eyebrows, or eyelashes. The hair loss typically occurs in clumps and may be accompanied by itching or a tingling sensation before the hair falls out.
#
# 3. Treatment / Management:
# There is no cure for alopecia areata, but various treatments can help promote hair regrowth and manage symptoms. Some effective treatment options include:
#
# ...

# %% [markdown]
# ### Query 4:  What treatments are recommended for a person who has sustained a physical injury to brain tissue, resulting in temporary or permanent impairment of brain function?

# %%
query = "What treatments are recommended for a person who has sustained a physical injury to brain tissue, resulting in temporary or permanent impairment of brain function?"

print(response(prompt + query))
# Out:
# Llama.generate: prefix-match hit
# 1. Definition:
# A traumatic brain injury (TBI) is an injury that results from external mechanical force, penetrating object, or blast wave causing disruption of brain function or other intracranial injuries. It can range from mild to severe and may result in temporary or permanent impairment of cognitive, physical, or emotional functions.
#
# 2. Symptoms:
# Symptoms vary depending on the severity and location of the injury but may include:
#    - Headache
#    - Loss of consciousness
#    - Memory loss
#    - Confusion
#    - Difficulty speaking or understanding speech
#    - Seizures
#    - Paralysis or weakness in limbs
#    - Sensory impairments (vision, hearing, touch)
#    - Emotional changes (anxiety, depression, irritability)
#
# 3. Treatment / Management:
#    - Initial management includes addressing life-threatening conditions such as airway obstruction, breathing difficulties, and excessive bleeding.
# ...

# %% [markdown]
# ### Query 5: What are the necessary precautions and treatment steps for a person who has fractured their leg during a hiking trip, and what should be considered for their care and recovery?

# %%
query = "What are the necessary precautions and treatment steps for a person who has fractured their leg during a hiking trip, and what should be considered for their care and recovery?"

print(response(prompt + query))
# Out:
# Llama.generate: prefix-match hit
# 1. Definition: A fracture is a break in a bone. In this context, we're discussing a fractured leg, which can occur due to various reasons such as falls or accidents while hiking.
#
# 2. Symptoms: The symptoms of a fractured leg may include:
#    - Severe pain in the affected leg
#    - Swelling and bruising around the injury site
#    - Difficulty moving the leg or bearing weight on it
#    - Deformity or misalignment of the limb (in severe cases)
#    - Numbness, tingling, or loss of sensation below the injury site (indicating nerve damage)
#
# 3. Treatment / Management:
#    a. Immediate Care: The first priority is to ensure the person's safety and prevent further injury. This may involve immobilizing the leg using a splint, sling, or other supportive devices. If the fracture is severe or open (compound), medical attention should be sought immediately.
#
# ...

# %% [markdown]
# The answers now follow a better well-rounded structure.

# %% [markdown]
# ## Data Preparation for RAG

# %%
from langchain_community.document_loaders import PyMuPDFLoader

# %% [markdown]
# ### Loading the Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
pdf_path = "/content/drive/MyDrive/medical_diagnosis_manual.pdf"

# %%
loader = PyMuPDFLoader(pdf_path)
manual = loader.load()
# loading data into manual

# %% [markdown]
# ### Data Overview

# %% [markdown]
# #### Checking the first 5 pages

# %%
for i in range(5):
    print(f"Page Number : {i+1}",end="\n")
    print(manual[i].page_content,end="\n")
# Out:
# Page Number : 1
# sutpat1@gmail.com
# UWOL2CK4S7
# This file is meant for personal use by sutpat1@gmail.com only.
# Sharing or publishing the contents in part or full is liable for legal action.
# Page Number : 2
# sutpat1@gmail.com
# UWOL2CK4S7
# This file is meant for personal use by sutpat1@gmail.com only.
# Sharing or publishing the contents in part or full is liable for legal action.
# Page Number : 3
# Table of Contents
# 1
# Front    ................................................................................................................................................................................................................
# 1
# Cover    .......................................................................................................................................................................................................
# 2
# ...

# %% [markdown]
# #### Checking the number of pages

# %%
print(len(manual))
# Out:
# 4114

# %% [markdown]
# ### Data Chunking

# %%
#chunking data with respective chunk size and overlap
text_splitter = RecursiveCharacterTextSplitter.from_tiktoken_encoder(
    encoding_name="cl100k_base",
    chunk_size=500,
    chunk_overlap=50
)

# %%
document_chunks = loader.load_and_split(text_splitter)

# %%
len(document_chunks)
# Out:
# 8853

# %% [markdown]
# Now going to check the chunks and their content

# %%
document_chunks[0].page_content
# Out:
# 'sutpat1@gmail.com\nUWOL2CK4S7\nThis file is meant for personal use by sutpat1@gmail.com only.\nSharing or publishing the contents in part or full is liable for legal action.'

# %%
document_chunks[1].page_content
# Out:
# 'sutpat1@gmail.com\nUWOL2CK4S7\nThis file is meant for personal use by sutpat1@gmail.com only.\nSharing or publishing the contents in part or full is liable for legal action.'

# %%
document_chunks[2].page_content
# Out:
# 'Table of Contents\n1\nFront    ................................................................................................................................................................................................................\n1\nCover    .......................................................................................................................................................................................................\n2\nFront Matter    ...........................................................................................................................................................................................\n53\n1 - Nutritional Disorders    ...............................................................................................................................................................\n53\nChapter 1. Nutrition: General Considerations    .........................................................................................
# ...

# %%
document_chunks[3].page_content
# Out:
# "275\nChapter 23. Approach to the Patient With Liver Disease    ...........................................................................................\n294\nChapter 24. Testing for Hepatic & Biliary Disorders    ......................................................................................................\n305\nChapter 25. Drugs & the Liver    ................................................................................................................................................\n308\nChapter 26. Alcoholic Liver Disease    ....................................................................................................................................\n314\nChapter 27. Fibrosis & Cirrhosis    ............................................................................................................................................\n322\nChapter 28. Hepatitis    ......................................................................................................
# ...

# %% [markdown]
# There is overlap between the content, and some repetition as the message for personal use is on every document.

# %% [markdown]
# ### Embedding

# %%
#creating the embedding model
embedding_model = SentenceTransformerEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

# %%
#creating embedding based on the first 2 chunks
embedding_1 = embedding_model.embed_query(document_chunks[0].page_content)
embedding_2 = embedding_model.embed_query(document_chunks[1].page_content)

# %%
print("Dimension of the embedding vector ",len(embedding_1))
len(embedding_1)==len(embedding_2)
# Out:
# Dimension of the embedding vector  384
# True

# %%
#the embedding coordinate values
embedding_1,embedding_2
# Out:
# ([-0.08997121453285217,
#   0.044427286833524704,
#   -0.0022343038581311703,
#   -0.02378043718636036,
#   0.083083376288414,
#   -0.051180385053157806,
#   0.021732110530138016,
#   0.0011162905720993876,
#   -0.029366284608840942,
#   -0.0024161774199455976,
#   0.07685475796461105,
#   0.10132081061601639,
#   0.03561258688569069,
#   -0.0893549695611,
#   -0.04582352191209793,
#   0.008976216427981853,
#   -0.034957729279994965,
#   -0.025269338861107826,
#   -0.06429626792669296,
#   -0.01833111234009266,
#   -0.005042082164436579,
#   -0.012822449207305908,
#   -0.03225938230752945,
#   -0.03541499748826027,
#   0.03752364590764046,
#   0.018580732867121696,
#   -0.06956429034471512,
#   0.01919625699520111,
#   -0.07187318801879883,
#   -0.0856572687625885,
#   0.03322519361972809,
#   -0.028901662677526474,
#   -0.0023739126045256853,
#   0.0333564467728138,
#   0.056136421859264374,
#   -0.008660337887704372,
#   0.027083249762654305,
#   -0.04938461259007454,
# ...

# %% [markdown]
# ### Vector Database

# %%
# making a vector data base from the chunks and embeddings
vector_db = Chroma.from_documents(
    documents=document_chunks,
    embedding=embedding_model
)

# %% [markdown]
# ### Retriever

# %%
# retriever for the RAG
retriever = vector_db.as_retriever(search_kwargs={"k": 3})

# %% [markdown]
# ### System and User Prompt Template

# %%
qna_system_message = """
You are a helpful AI healthcare assistant.
Answer the user's question using only the provided context.
If the answer is not present in the context, say
'I don't have enough information to answer that question.'
Be concise and accurate.
"""

# %%
qna_user_message_template = """
Context:
{context}

Question:
{question}

Answer:
"""

# %% [markdown]
# I used a general format template, which is is not too rigid with bullet points, but structured enough in way that is easy to understand in the output.

# %% [markdown]
# ### Response Function

# %%
def generate_rag_response(user_input,k=3,max_tokens=128,temperature=0,top_p=0.95,top_k=50):
    global qna_system_message,qna_user_message_template
    # Retrieve relevant document chunks
    relevant_document_chunks = retriever.get_relevant_documents(query=user_input,k=k)
    context_list = [d.page_content for d in relevant_document_chunks]

    # Combine document chunks into a single context
    context_for_query = ". ".join(context_list)

    user_message = qna_user_message_template.replace('{context}', context_for_query)
    user_message = user_message.replace('{question}', user_input)

    prompt = qna_system_message + '\n' + user_message

    # Generate the response
    try:
        response = llm(
                  prompt=prompt,
                  max_tokens=max_tokens,
                  temperature=temperature,
                  top_p=top_p,
                  top_k=top_k
                  )

        # Extract and print the model's response
        response = response['choices'][0]['text'].strip()
    except Exception as e:
        response = f'Sorry, I encountered the following error: \n {e}'

    return response

# %% [markdown]
# ## Question Answering using RAG

# %% [markdown]
# ### Query 1: What is the protocol for managing sepsis in a critical care unit?

# %%
question = "What is the protocol for managing sepsis in a critical care unit?"
generate_rag_response(question,top_k=20)
# Out:
# Llama.generate: prefix-match hit
# "The context does not provide specific information on the protocol for managing sepsis in a critical care unit. However, it mentions that prevention of infection is an important aspect of supportive care for ICU patients (see p. 131). If a patient develops sepsis, they would likely receive appropriate antibiotic therapy and intensive fluid resuscitation to maintain adequate tissue perfusion. Close monitoring of vital signs, lactate levels, and organ function is essential. The use of point-of-care testing may be helpful in guiding management. It's important to follow hospital protocols for seps"

# %% [markdown]
# ### Query 2: What are the common symptoms for appendicitis, and can it be cured via medicine? If not, what surgical procedure should be followed to treat it?

# %%
question = "What are the common symptoms for appendicitis, and can it be cured via medicine? If not, what surgical procedure should be followed to treat it?"
generate_rag_response(question,top_k=20)
# Out:
# Llama.generate: prefix-match hit
# "The common symptoms for appendicitis include epigastric or periumbilical pain followed by brief nausea, vomiting, and anorexia, which later shifts to the right lower quadrant. Pain increases with cough and motion. Classic signs are right lower quadrant direct and rebound tenderness located at McBurney's point. Additional signs include pain felt in the right lower quadrant with palpation of the left lower quadrant (Rovsing sign), an increase in pain from passive extension of the right hip joint that stretches the iliopsoas muscle (psoas sign),"

# %% [markdown]
# ### Query 3: What are the effective treatments or solutions for addressing sudden patchy hair loss, commonly seen as localized bald spots on the scalp, and what could be the possible causes behind it?

# %%
question = "What are the effective treatments or solutions for addressing sudden patchy hair loss, commonly seen as localized bald spots on the scalp, and what could be the possible causes behind it?"
generate_rag_response(question,top_k=20)
# Out:
# Llama.generate: prefix-match hit
# 'Sudden patchy hair loss, also known as alopecia areata, is a common autoimmune disorder that affects genetically susceptible individuals. The exact cause of this condition is unclear but may involve environmental triggers. Effective treatments for alopecia areata include topical corticosteroids, oral antimalarials, corticosteroids, retinoids, or immunosuppressants. A thorough evaluation is necessary if concomitant virilization in women or scarring hair loss is present to rule out underlying disorders. Microscopic hair examination or scalp bi'

# %% [markdown]
# ### Query 4:  What treatments are recommended for a person who has sustained a physical injury to brain tissue, resulting in temporary or permanent impairment of brain function?

# %%
question = "What treatments are recommended for a person who has sustained a physical injury to brain tissue, resulting in temporary or permanent impairment of brain function?"
generate_rag_response(question,top_k=20)
# Out:
# Llama.generate: prefix-match hit
# 'For a person with a head injury or traumatic brain injury (TBI), early intervention by rehabilitation specialists is crucial for maximal functional recovery. Rehabilitation includes prevention of secondary disabilities such as pressure ulcers and joint contractures, prevention of pneumonia, and family education. Patients should be evaluated to establish baseline findings, and later, before starting therapy, they should be reevaluated to help prioritize treatment. Patients with severe cognitive dysfunction require extensive cognitive therapy which is often begun immediately after injury and continued for months or years. For spinal cord injuries, specific rehabilitation therapy varies depending on'

# %% [markdown]
# ### Query 5: What are the necessary precautions and treatment steps for a person who has fractured their leg during a hiking trip, and what should be considered for their care and recovery?

# %%
question = "What are the necessary precautions and treatment steps for a person who has fractured their leg during a hiking trip, and what should be considered for their care and recovery?"
generate_rag_response(question,top_k=20)
# Out:
# Llama.generate: prefix-match hit
# 'For a person with a fractured leg from a hiking trip, the following steps should be taken:\n1. Assess for life-threatening injuries or signs of hemorrhagic shock. If present, seek immediate medical attention.\n2. Immobilize the injured leg using a nonrigid or noncircumferential splint to prevent further injury and decrease pain. This may also help prevent fat embolism in long-bone fractures.\n3. Apply RICE (rest, ice, compression, elevation) principles to minimize swelling, pain, and promote healing. Use a spl'

# %% [markdown]
# ### Fine-tuning

# %% [markdown]
# ### Query 1: What is the protocol for managing sepsis in a critical care unit?

# %%
question = "What is the protocol for managing sepsis in a critical care unit?"
generate_rag_response(question,top_k=20, temperature = 0.1)
# Out:
# Llama.generate: prefix-match hit
# 'The context does not provide specific information on the protocol for managing sepsis in a critical care unit. However, it mentions that prevention of infection is an important aspect of supportive care for ICU patients (see p. 131). If a patient develops sepsis, they would likely receive appropriate antibiotic therapy, fluid resuscitation, and other supportive measures as needed. Blood tests, including blood cultures, would be ordered to help diagnose and monitor the infection. Continuous monitoring of vital signs and other physiologic parameters is also essential for managing sepsis in a critical care unit.'

# %% [markdown]
# ### Query 2: What are the common symptoms for appendicitis, and can it be cured via medicine? If not, what surgical procedure should be followed to treat it?

# %%
question = "What are the common symptoms for appendicitis, and can it be cured via medicine? If not, what surgical procedure should be followed to treat it?"
generate_rag_response(question,top_k=20, temperature = 0.5)
# Out:
# Llama.generate: prefix-match hit
# "The common symptoms for appendicitis include epigastric or periumbilical pain followed by brief nausea, vomiting, and anorexia, which later shifts to the right lower quadrant. Pain increases with cough and motion. Classic signs are direct and rebound tenderness located at McBurney's point (junction of the middle and outer thirds of the line joining the umbilicus to the anterior superior spine). Additional signs include pain felt in the right lower quadrant with palpation of the left lower quadrant (Rovsing sign), an increase in pain from passive extension"

# %% [markdown]
# ### Query 3: What are the effective treatments or solutions for addressing sudden patchy hair loss, commonly seen as localized bald spots on the scalp, and what could be the possible causes behind it?

# %%
question = "What are the effective treatments or solutions for addressing sudden patchy hair loss, commonly seen as localized bald spots on the scalp, and what could be the possible causes behind it?"
generate_rag_response(question,top_k=20, temperature = 1.0)
# Out:
# Llama.generate: prefix-match hit
# "Sudden patchy hair loss, also known as alopecia areata, can be treated with topical corticosteroids. In cases where more extensive hair loss is present or when other areas of the body are affected, oral medications such as corticosteroids, antimalarials, retinoids, or immunosuppressants may be considered. The exact cause of alopecia areata is not known but it's believed to be an autoimmune disorder affecting genetically susceptible individuals exposed to unclear environmental triggers. Concomitant virilization or scarring hair"

# %% [markdown]
# ### Query 4:  What treatments are recommended for a person who has sustained a physical injury to brain tissue, resulting in temporary or permanent impairment of brain function?

# %%
question = "What treatments are recommended for a person who has sustained a physical injury to brain tissue, resulting in temporary or permanent impairment of brain function?"
generate_rag_response(question,top_k=20, temperature = 0.8)
# Out:
# Llama.generate: prefix-match hit
# 'The Merck Manual recommends early intervention by rehabilitation specialists for maximal functional recovery from head injuries, which include prevention of secondary disabilities such as pressure ulcers and joint contractures, prevention of pneumonia, and family education. Patients with severe cognitive dysfunction require extensive cognitive therapy immediately after injury and continued for months or years. Spinal cord injury treatments depend on the level and extent of the injury, causing either flaccid paralysis or spastic paralysis. During the acute phase, measures to prevent contractures, pressure ulcers, pneumonia, and other complications are necessary. Imm'

# %% [markdown]
# ### Query 5: What are the necessary precautions and treatment steps for a person who has fractured their leg during a hiking trip, and what should be considered for their care and recovery?

# %%
question = "What are the necessary precautions and treatment steps for a person who has fractured their leg during a hiking trip, and what should be considered for their care and recovery?"
generate_rag_response(question,top_k=20, temperature = 0.3)
# Out:
# Llama.generate: prefix-match hit
# 'For a person who has fractured their leg during a hiking trip, the following precautions and treatment steps should be taken:\n1. Assess the severity of the injury and check for any signs of life-threatening conditions such as hemorrhagic shock or arterial injuries. If necessary, seek emergency medical help.\n2. Immediately immobilize the leg to prevent further injury and decrease pain by splinting with a nonrigid or noncircumferential device.\n3. Apply RICE (rest, ice, compression, elevation) to minimize swelling and'

# %% [markdown]
# The temperature fine-tuning is used whether I want a more creative response for a question or a more grounded, logical one.

# %% [markdown]
# ## Output Evaluation

# %% [markdown]
# Let us now use the LLM-as-a-judge method to check the quality of the RAG system on two parameters - retrieval and generation. We illustrate this evaluation based on the answeres generated to the question from the previous section.
#
# - We are using the same Mistral model for evaluation, so basically here the llm is rating itself on how well he has performed in the task.

# %%
groundedness_rater_system_message  = """
You are an expert evaluator of Retrieval-Augmented Generation (RAG) systems.

Your task is to determine whether the answer is fully supported by the provided context.

Instructions:
- Give a score from 1 to 5.
- 1 = Not grounded at all.
- 5 = Completely grounded in the context.
- Explain your reasoning.
- Do not use outside knowledge.
"""

# %%
relevance_rater_system_message = """You are an expert evaluator of question-answering systems.

Your task is to determine whether the answer is relevant to the user's question.

Instructions:
- Give a score from 1 to 5.
- 1 = Completely irrelevant.
- 5 = Fully answers the question.
- Explain your reasoning.
"""

# %%
user_message_template = """
Context:
{context}

Question:
{question}

Answer:
{answer}

Evaluate the answer according to your instructions.
"""

# %%
def generate_ground_relevance_response(user_input,k=3,max_tokens=128,temperature=0,top_p=0.95,top_k=50):
    global qna_system_message,qna_user_message_template
    # Retrieve relevant document chunks
    relevant_document_chunks = retriever.get_relevant_documents(query=user_input,k=3)
    context_list = [d.page_content for d in relevant_document_chunks]
    context_for_query = ". ".join(context_list)

    # Combine user_prompt and system_message to create the prompt
    prompt = f"""[INST]{qna_system_message}\n
                {'user'}: {qna_user_message_template.format(context=context_for_query, question=user_input)}
                [/INST]"""

    response = llm(
            prompt=prompt,
            max_tokens=max_tokens,
            temperature=temperature,
            top_p=top_p,
            top_k=top_k,
            stop=['INST'],
            )

    answer =  response["choices"][0]["text"]

    # Combine user_prompt and system_message to create the prompt
    groundedness_prompt = f"""[INST]{groundedness_rater_system_message}\n
                {'user'}: {user_message_template.format(context=context_for_query, question=user_input, answer=answer)}
                [/INST]"""

    # Combine user_prompt and system_message to create the prompt
    relevance_prompt = f"""[INST]{relevance_rater_system_message}\n
                {'user'}: {user_message_template.format(context=context_for_query, question=user_input, answer=answer)}
                [/INST]"""

    response_1 = llm(
            prompt=groundedness_prompt,
            max_tokens=max_tokens,
            temperature=temperature,
            top_p=top_p,
            top_k=top_k,
            stop=['INST'],
            )

    response_2 = llm(
            prompt=relevance_prompt,
            max_tokens=max_tokens,
            temperature=temperature,
            top_p=top_p,
            top_k=top_k,
            stop=['INST'],
            )

    return response_1['choices'][0]['text'],response_2['choices'][0]['text']

# %% [markdown]
# ### Query 1: What is the protocol for managing sepsis in a critical care unit?

# %%
ground, relevance = generate_ground_relevance_response(user_input="What is the protocol for managing sepsis in a critical care unit?",max_tokens=300)

# adding a blank line in between
print(ground,end="\n\n")

print(relevance)
# Out:
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
#  Score: 3
#
# Reasoning: The context does provide information on the importance of preventing infection in ICU patients (p. 131), which implies that there is a protocol for managing sepsis, a life-threatening condition caused by the body's response to infection. However, the context does not explicitly state what the protocol entails. Therefore, the answer is partially grounded in the context.
#
#  Score: 3
#
# ...

# %% [markdown]
# ### Query 2: What are the common symptoms for appendicitis, and can it be cured via medicine? If not, what surgical procedure should be followed to treat it?

# %%
ground, relevance = generate_ground_relevance_response(user_input="What are the common symptoms for appendicitis, and can it be cured via medicine? If not, what surgical procedure should be followed to treat it?",max_tokens=300)

# adding a blank line in between
print(ground,end="\n\n")

print(relevance)
# Out:
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
#  I would give the answer a score of 5. The answer accurately summarizes the common symptoms of appendicitis as described in the context, and it correctly states that appendicitis cannot be cured via medicine alone if the appendix becomes necrotic or perforated. The answer also provides an accurate description of the surgical procedure for treating appendicitis, which is called an appendectomy.
#
#  Score: 5
#
# Reasoning: The answer fully addresses the user's question by providing a clear explanation of the common symptoms for appendicitis and stating that surgery (appendectomy) is necessary when the appendix becomes necrotic or perforated, which cannot be cured via medicine. The answer also mentions the surgical procedure used to treat appendicitis.

# %% [markdown]
# ### Query 3: What are the effective treatments or solutions for addressing sudden patchy hair loss, commonly seen as localized bald spots on the scalp, and what could be the possible causes behind it?

# %%
ground, relevance = generate_ground_relevance_response(user_input="What are the effective treatments or solutions for addressing sudden patchy hair loss, commonly seen as localized bald spots on the scalp, and what could be the possible causes behind it?",max_tokens=300)

# adding a blank line in between
print(ground,end="\n\n")

print(relevance)
# Out:
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
#  Score: 5
#
# Reasoning: The answer is fully grounded in the context as it accurately identifies alopecia areata as a cause of sudden patchy hair loss, mentions the effective treatments for this condition from the context (topical corticosteroids, oral antimalarials, corticosteroids, retinoids, or immunosuppressants), and explains the underlying cause as an autoimmune disorder based on the information provided.
#
#  Score: 5
#
# ...

# %% [markdown]
# ### Query 4: What treatments are recommended for a person who has sustained a physical injury to brain tissue, resulting in temporary or permanent impairment of brain function?

# %%
ground, relevance = generate_ground_relevance_response(user_input="What treatments are recommended for a person who has sustained a physical injury to brain tissue, resulting in temporary or permanent impairment of brain function?",max_tokens=300)

# adding a blank line in between
print(ground,end="\n\n")

print(relevance)
# Out:
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
#  I would give the answer a score of 5. The context clearly states that rehabilitation specialists play an essential role in the recovery process for patients with head injuries and spinal cord injuries, and it outlines specific treatments and interventions for both types of injuries. The answer accurately summarizes this information and provides details on the importance of early intervention, prevention of secondary disabilities, and various forms of therapy for cognitive dysfunction and immobilization during the acute phase for spinal cord injuries.
#
#  Score: 5
#
# ...

# %% [markdown]
# ### Query 5: What are the necessary precautions and treatment steps for a person who has fractured their leg during a hiking trip, and what should be considered for their care and recovery?

# %%
ground, relevance = generate_ground_relevance_response(user_input="What are the necessary precautions and treatment steps for a person who has fractured their leg during a hiking trip, and what should be considered for their care and recovery?",max_tokens=300)

# adding a blank line in between
print(ground,end="\n\n")

print(relevance)
# Out:
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
# Llama.generate: prefix-match hit
#  Score: 5
#
# Reasoning: The answer fully supports the context by summarizing the necessary precautions and treatment steps for a person with a fractured leg, including immobilization, pain management, definitive treatment, RICE therapy, and potential additional tests for arterial or nerve injuries. The answer is completely grounded in the provided context.
#
#  Score: 5
#
# Reasoning: The answer fully answers the question by providing a comprehensive list of precautions and treatment steps for a person with a fractured leg, including immobilization methods, pain management, definitive treatment options, RICE therapy, and potential additional tests or treatments based on specific injuries.

# %% [markdown]
# The scores of 5 show that the model gives responses that are grounded and relevant.

# %% [markdown]
# ## Actionable Insights and Business Recommendations

# %% [markdown]
# Actionable Insights
#
# * The RAG system effectively retrieves relevant information across a variety of medical topics.
# * High groundedness ensures responses are supported by retrieved documents, reducing hallucinations.
# *  Regular evaluation with diverse healthcare queries helps maintain accuracy and reliability.
# * Expanding the medical knowledge base can further improve response quality.

# %% [markdown]
# Business Recommendations
#
# * Continuously update the knowledge base with the latest clinical guidelines and medical research.
# * Monitor groundedness and relevance metrics to maintain consistent system performance.
# * Implement confidence thresholds and human review for high-risk medical queries.
# * Collect user feedback to continuously improve retrieval accuracy and response quality.

# %% [markdown]
# <font size=6 color='blue'>Power Ahead</font>
# ___
